# %% [markdown]
# <a href="https://colab.research.google.com/github/TSQTT-Cyber-Lab/AI-Research-SKILLs/blob/main/DeepFake_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# !git clone https://github.com/TSQTT-Cyber-Lab/SnFormer-VNICT2026.git
# %cd SnFormer-VNICT2026
# Out:
# /content
# fatal: destination path 'SnFormer-VNICT2026' already exists and is not an empty directory.
# /content/SnFormer-VNICT2026

# %%
# !pip install torch torchvision opencv-python-headless pillow --quiet

# %%
import torch
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'Không có GPU!'}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
import os

# Bước 1: Tìm mount point đúng (MyDrive hay "My Drive")
drive_root = None
for candidate in ["/content/drive/MyDrive", "/content/drive/My Drive"]:
    if os.path.exists(candidate):
        drive_root = candidate
        break

print(f"Drive root: {drive_root}")

# Bước 2: Liệt kê để bạn tự chọn đúng folder
for item in sorted(os.listdir(drive_root)):
    print(f"  {item}/")
# Out:
# Drive root: /content/drive/MyDrive
#   AI/
#   Agentic AI: Kỷ nguyên "Đồng nghiệp số" trong Giảng dạy và Nghiên cứu.gslides/
#   Bài 1 - Tổng quan.gslides/
#   Bạn là chuyên gia hàng đầu trong lĩnh vực AI, hãy.../
#   Camera/
#   Colab Notebooks/
#   Music/
#   Nghiên cứu AI trong GD&NCKH.gslides/
#   Nghiên cứu IDS Quantum Neuro-Symbolic cho IoT Smart City - TS. Phan Thanh Sơn.gdoc/
#   Nghiên cứu IDS Quantum Neuro-Symbolic cho Smart City - TS. Phan Thanh Sơn.gdoc/
#   Nghiên cứu: Tích hợp Kiểm soát Cảm xúc Thời gian thực vào Mô hình PersonaLive.gdoc/
#   Opal/
#   Quy trình Làm Video AI chuyên nghiệp bằng GG Flow.gdoc/
#   SnFormer/
#   TBG Python/
#   Untitled presentation.gslides/
#   Untitled video.gvid/
#   data/
#   Định dạng tài liệu theo mẫu APA 7.gdoc/

# %%
# Thay bằng đường dẫn thực tế bạn thấy ở trên
DATA_DIR = f"{drive_root}/SnFormer/data/train"   # chỉnh lại nếu khác

# Xác nhận
print(f"DATA_DIR = {DATA_DIR}")
print(f"Tồn tại: {os.path.exists(DATA_DIR)}")
if os.path.exists(DATA_DIR):
    for sub in os.listdir(DATA_DIR):
        print(f"  {sub}/")
# Out:
# DATA_DIR = /content/drive/MyDrive/SnFormer/data/train
# Tồn tại: True
#   real/
#   test/
#   fake/
#   dataset.py/
#   __init__.py/
#   trainer.py/

# %%
# !python train/trainer.py \
  --stage 1 \
  --data-dir "{DATA_DIR}" \
  --epochs 30 \
  --batch-size 8 \
  --num-frames 8 \
  --num-workers 2 \
  --lr 1e-4
# Out:
# Sformer/SnFormer Training Pipeline
# Device: CUDA | Stage: 1
#   Found 3917 real samples in /content/drive/MyDrive/SnFormer/data/train/real
#   Found 795 fake samples in /content/drive/MyDrive/SnFormer/data/train/fake
#   Dataset: 4241 train / 471 val samples
#
# ──────────────────────────────────────────────────
# Stage 1: Pretrain Sformer-Full (full precision)
#   epochs=30, lr=0.0001, device=cuda
#   train_batches=530, val_batches=59
# ──────────────────────────────────────────────────
